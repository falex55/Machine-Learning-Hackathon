# %% [markdown]
# # Task 1 : Data Analysis
#  You have been given some infant and mother’s information who have given birth to
# their baby. Data Analyst have collected the data from hospital. With the help of data science and
# machine learning, you should understand the relationship between mother and their baby.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import time

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('childbirth.csv')

# %%
df.sample(5)
# Out:
#           BabyId  FirsttimeParent Crying date Crying time  Crying seconds  \
# 1132  HPT2_NR_27                0    08/16/15    23:15:00             NaN
# 1458  HPT2_NR_30                0    08/08/15    23:45:00             NaN
# 620   HPT2_NR_21                1    08/19/15    23:30:00             NaN
# 1660  HPT2_NR_31                1    08/06/15    10:30:00             NaN
# 1584  HPT2_NR_31                1    07/27/15     6:15:00             NaN
#
#      Feeding date Feeding time  Bottle amount PumpingDate  \
# 1132     08/16/15     23:15:00          200.0    08/16/15
# 1458     08/08/15     23:45:00          120.0    08/08/15
# 620      08/19/15     23:30:00            NaN    08/19/15
# 1660     08/06/15     10:30:00           95.0    08/06/15
# 1584     07/27/15      6:15:00          110.0    07/27/15
#
#      PumpingTimePumpingLeftPumpingRight  Pumping Left  PumpingRight  \
# 1132                           23:15:00           NaN           NaN
# ...

# %%
df.shape
# Out:
# (1773, 15)

# %%
# Checking for null values 
df.isnull().sum()
# Out:
# BabyId                                   0
# FirsttimeParent                          0
# Crying date                              0
# Crying time                              0
# Crying seconds                        1700
# Feeding date                             0
# Feeding time                             0
# Bottle amount                          729
# PumpingDate                              0
# PumpingTimePumpingLeftPumpingRight       0
# Pumping Left                          1712
# PumpingRight                          1705
# SleepingDate                             0
# SleepingTime                             0
# SleepingSecond                         777
# dtype: int64

# %%
# Drop the column which are having more then half data with NaN values
df.drop(['Crying seconds','Pumping Left','PumpingRight','SleepingSecond'],axis=1, inplace = True)
df
# Out:
#           BabyId  FirsttimeParent Crying date Crying time Feeding date  \
# 0     HPT2_NR_16                1    08/05/15    20:31:47     08/05/15
# 1     HPT2_NR_16                1    08/05/15    23:33:46     08/05/15
# 2     HPT2_NR_16                1    08/06/15    10:20:00     08/06/15
# 3     HPT2_NR_16                1    08/06/15    11:30:00     08/06/15
# 4     HPT2_NR_16                1    08/06/15    12:15:00     08/06/15
# ...          ...              ...         ...         ...          ...
# 1768  HPT2_NR_33                1    08/20/15    20:30:00     08/20/15
# 1769  HPT2_NR_33                1    08/21/15     0:00:00     08/21/15
# 1770  HPT2_NR_33                1    08/21/15     4:30:00     08/21/15
# 1771  HPT2_NR_33                1    08/21/15     9:00:00     08/21/15
# 1772  HPT2_NR_33                1    08/21/15    12:10:00     08/21/15
#
#      Feeding time  Bottle amount PumpingDate  \
# 0        20:31:47          180.0    08/05/15
# ...

# %%
df.isnull().sum()
# Out:
# BabyId                                  0
# FirsttimeParent                         0
# Crying date                             0
# Crying time                             0
# Feeding date                            0
# Feeding time                            0
# Bottle amount                         729
# PumpingDate                             0
# PumpingTimePumpingLeftPumpingRight      0
# SleepingDate                            0
# SleepingTime                            0
# dtype: int64

# %%
df.dropna(axis=0, how='all', subset=['Bottle amount'], inplace = True)
df.shape
# Out:
# (1044, 11)

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (1044, 11)
# BabyId             0
# FirsttimeParent    0
# Crying date        0
# Crying time        0
# Feeding date       0
# Feeding time       0
# Bottle amount      0
# PumpingDate        0
# PumpingTime        0
# SleepingDate       0
# SleepingTime       0
# dtype: int64

# %% [markdown]
# ##### Noe there is no any null value we can forward to the next step

# %%
# Rename the column
df.rename(columns={"PumpingTimePumpingLeftPumpingRight":"PumpingTime"},inplace=True)

# %%
df.sample(5)
# Out:
#           BabyId  FirsttimeParent Crying date Crying time Feeding date  \
# 442   HPT2_NR_20                1    08/16/15    13:45:00     08/16/15
# 1538  HPT2_NR_30                0    08/20/15    15:00:00     08/20/15
# 1489  HPT2_NR_30                0    08/13/15    17:00:00     08/13/15
# 1097  HPT2_NR_27                0    08/04/15     4:10:00     08/04/15
# 1586  HPT2_NR_31                1    07/27/15    12:00:00     07/27/15
#
#      Feeding time  Bottle amount PumpingDate PumpingTime SleepingDate  \
# 442      13:45:00           60.0    08/16/15    13:45:00     08/16/15
# 1538     15:00:00           60.0    08/20/15    15:00:00     08/20/15
# 1489     17:00:00          120.0    08/13/15    17:00:00     08/13/15
# 1097      4:10:00          150.0    08/04/15     4:10:00     08/04/15
# 1586     12:00:00          130.0    07/27/15    12:00:00     07/27/15
#
#      SleepingTime
# 442      13:45:00
# 1538     15:00:00
# 1489     17:00:00
# 1097      4:10:00
# 1586     12:00:00

# %%
# counts of babies
df['BabyId'].value_counts()
# Out:
# HPT2_NR_30    199
# HPT2_NR_20    170
# HPT2_NR_31    169
# HPT2_NR_29    104
# HPT2_NR_24     91
# HPT2_NR_27     83
# HPT2_NR_18     77
# HPT2_NR_16     69
# HPT2_NR_19     32
# HPT2_NR_21     15
# HPT2_NR_26     10
# HPT2_NR_22     10
# HPT2_NR_28      8
# HPT2_NR_17      6
# HPT2_NR_23      1
# Name: BabyId, dtype: int64

# %%
# max count of amount for each baby
baby_milk_amount_count = df.groupby(by=['BabyId'], as_index=False)['Bottle amount'].count()
baby_milk_amount_count.sample(5)
# Out:
#         BabyId  Bottle amount
# 13  HPT2_NR_30            199
# 4   HPT2_NR_20            170
# 7   HPT2_NR_23              1
# 6   HPT2_NR_22             10
# 2   HPT2_NR_18             77

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6)
plt.plot(baby_milk_amount_count['BabyId'], baby_milk_amount_count['Bottle amount'])
plt.xlabel('Baby ID', fontsize = 12)
plt.xticks(rotation=90)
plt.ylabel('amount', fontsize = 12)
plt.title('Maximum Milk Amount for each baby \n')
plt.show()

# %%
# sum of amount for each baby
baby_milk_amount = df.groupby(by=['BabyId'], as_index=False)['Bottle amount'].sum()
baby_milk_amount.sample(5)
# Out:
#         BabyId  Bottle amount
# 0   HPT2_NR_16        12135.0
# 12  HPT2_NR_29        18130.0
# 3   HPT2_NR_19         2175.0
# 2   HPT2_NR_18        11165.0
# 13  HPT2_NR_30        23200.0

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6)
plt.plot(baby_milk_amount['BabyId'], baby_milk_amount['Bottle amount'], color = 'red')
plt.xlabel('Baby ID', fontsize = 12)
plt.xticks(rotation=90)
plt.ylabel('Bottle amount', fontsize = 12)
plt.title('Babies Overall Milk Amount \n')
plt.show()

# %%
df.head()
# Out:
#        BabyId  FirsttimeParent Crying date Crying time Feeding date  \
# 0  HPT2_NR_16                1    08/05/15    20:31:47     08/05/15
# 1  HPT2_NR_16                1    08/05/15    23:33:46     08/05/15
# 2  HPT2_NR_16                1    08/06/15    10:20:00     08/06/15
# 3  HPT2_NR_16                1    08/06/15    11:30:00     08/06/15
# 4  HPT2_NR_16                1    08/06/15    12:15:00     08/06/15
#
#   Feeding time  Bottle amount PumpingDate PumpingTime SleepingDate  \
# 0     20:31:47          180.0    08/05/15    20:31:47     08/05/15
# 1     23:33:46          180.0    08/05/15    23:33:46     08/05/15
# 2     10:20:00          180.0    08/06/15    10:20:00     08/06/15
# 3     11:30:00           35.0    08/06/15    11:30:00     08/06/15
# 4     12:15:00          180.0    08/06/15    12:15:00     08/06/15
#
#   SleepingTime
# 0     20:31:47
# 1     23:33:46
# 2     10:20:00
# 3     11:30:00
# 4     12:15:00

# %%
# Counts Of first_time_parents vs not a First time parents

fig = plt.gcf()
fig.set_size_inches(10, 6)
counts = df.FirsttimeParent.value_counts()
plt.pie(counts, autopct='%1.1f%%',
        labels=['First_time_parents','Not_first_time_parents'], shadow=True)
plt.title('\n Counts Of first_time_parents vs not a First time parents', fontsize = 15)
plt.show()

# %%
df.sample()
# Out:
#          BabyId  FirsttimeParent Crying date Crying time Feeding date  \
# 864  HPT2_NR_24                1    08/12/15     6:20:00     08/12/15
#
#     Feeding time  Bottle amount PumpingDate PumpingTime SleepingDate  \
# 864      6:20:00           70.0    08/12/15     6:20:00     08/12/15
#
#     SleepingTime
# 864      6:20:00

# %%
# how many time baby cried for particular date 

crying_baby = df[['FirsttimeParent','BabyId','Crying date']]
crying_baby_group = crying_baby.groupby(['Crying date','BabyId'],as_index=False).count()
crying_baby_group_pivot = crying_baby_group.pivot(index='BabyId',columns='Crying date')
crying_baby_group_pivot
# Out:
#             FirsttimeParent                                               \
# Crying date        07/22/15 07/23/15 07/24/15 07/25/15 07/26/15 07/27/15
# BabyId
# HPT2_NR_16              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_17              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_18              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_19              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_20              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_21              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_22              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_23              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_24              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_26              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_27              NaN      4.0      6.0      3.0      3.0      4.0
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(15, 6)
map = sns.heatmap(crying_baby_group_pivot, annot = True, cmap='Greens')
plt.title('\n Baby cried on perticular date \n')
plt.xlabel('dates')
for _, spine in map.spines.items():
    spine.set_visible(True)

# %%
# feeding count on particular date 

feeding_baby = df[['FirsttimeParent','BabyId','Crying date']]
feeding_baby_group = feeding_baby.groupby(['Crying date','BabyId'],as_index=False).count()
feeding_baby_group_pivot = feeding_baby_group.pivot(index='BabyId',columns='Crying date')
feeding_baby_group_pivot
# Out:
#             FirsttimeParent                                               \
# Crying date        07/22/15 07/23/15 07/24/15 07/25/15 07/26/15 07/27/15
# BabyId
# HPT2_NR_16              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_17              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_18              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_19              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_20              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_21              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_22              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_23              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_24              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_26              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_27              NaN      4.0      6.0      3.0      3.0      4.0
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(15, 6)
map = sns.heatmap(feeding_baby_group_pivot, annot = True, cmap='cividis')
plt.title('\n feeding count on perticular date \n')
plt.xlabel('dates')
for _, spine in map.spines.items():
    spine.set_visible(True)

# %%
# how many times baby pumped for particular date 

pumping_baby = df[['FirsttimeParent','BabyId','Crying date']]
pumping_baby_group = pumping_baby.groupby(['Crying date','BabyId'],as_index=False).count()
pumping_baby_group_pivot = pumping_baby_group.pivot(index='BabyId',columns='Crying date')
pumping_baby_group_pivot
# Out:
#             FirsttimeParent                                               \
# Crying date        07/22/15 07/23/15 07/24/15 07/25/15 07/26/15 07/27/15
# BabyId
# HPT2_NR_16              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_17              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_18              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_19              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_20              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_21              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_22              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_23              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_24              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_26              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_27              NaN      4.0      6.0      3.0      3.0      4.0
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(15, 6)
map = sns.heatmap(pumping_baby_group_pivot, annot = True, cmap='coolwarm')
plt.title('\n pumping count on perticular date \n')
plt.xlabel('dates')
for _, spine in map.spines.items():
    spine.set_visible(True)

# %%
# how many time baby sleep for particular date
sleeping_baby = df[['FirsttimeParent','BabyId','Crying date']]
sleeping_baby_group = sleeping_baby.groupby(['Crying date','BabyId'],as_index=False).count()
sleeping_baby_group_pivot = sleeping_baby_group.pivot(index='BabyId',columns='Crying date')
sleeping_baby_group_pivot
# Out:
#             FirsttimeParent                                               \
# Crying date        07/22/15 07/23/15 07/24/15 07/25/15 07/26/15 07/27/15
# BabyId
# HPT2_NR_16              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_17              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_18              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_19              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_20              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_21              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_22              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_23              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_24              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_26              NaN      NaN      NaN      NaN      NaN      NaN
# HPT2_NR_27              NaN      4.0      6.0      3.0      3.0      4.0
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(15, 6)
map = sns.heatmap(sleeping_baby_group_pivot, annot = True, cmap='coolwarm')
plt.title('\n sleeping count on perticular date \n')
plt.xlabel('dates')
for _, spine in map.spines.items():
    spine.set_visible(True)

# %% [markdown]
# # Task 2 : Model building

# %%
import math

# %%
df2 = pd.read_csv('D:/Board Infinity 2/Hackathon/ML/birth.csv')

# %%
df2.head()
# Out:
#    Mom_weight  Mom_height  Mom_Age  Religion  Gender  Birth_Weight
# 0          41         152       25         1       1          2.06
# 1          42         157       25         3       1          1.70
# 2          44         153       23         2       1          1.59
# 3          45         177       19         2       1          2.73
# 4          46         160       19         2       1          2.08

# %%
df2.isnull().sum()
# Out:
# Mom_weight      0
# Mom_height      0
# Mom_Age         0
# Religion        0
# Gender          0
# Birth_Weight    0
# dtype: int64

# %%
df2.dtypes
# Out:
# Mom_weight        int64
# Mom_height        int64
# Mom_Age           int64
# Religion          int64
# Gender            int64
# Birth_Weight    float64
# dtype: object

# %%
df2.describe()
# Out:
#        Mom_weight  Mom_height     Mom_Age    Religion      Gender  \
# count  189.000000  189.000000  189.000000  189.000000  189.000000
# mean    65.089947  172.026455   23.238095    1.793651    1.232804
# std      9.966826    8.978363    5.298678    0.808704    0.423741
# min     41.000000  151.000000   14.000000    1.000000    1.000000
# 25%     59.000000  166.000000   19.000000    1.000000    1.000000
# 50%     69.000000  174.000000   23.000000    2.000000    1.000000
# 75%     73.000000  178.000000   26.000000    2.000000    1.000000
# max     79.000000  189.000000   45.000000    3.000000    2.000000
#
#        Birth_Weight
# count    189.000000
# mean       2.936508
# std        0.645921
# min        1.500000
# 25%        2.440000
# 50%        2.980000
# 75%        3.440000
# max        4.150000

# %%
# there is no any null value
sns.heatmap(df2.isnull(),yticklabels = False)
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#    Mom_weight  Mom_height  Mom_Age  Religion  Gender  Birth_Weight
# 0          41         152       25         1       1          2.06
# 1          42         157       25         3       1          1.70
# 2          44         153       23         2       1          1.59
# 3          45         177       19         2       1          2.73
# 4          46         160       19         2       1          2.08

# %%
the spread of the data 
sns.pairplot(df2)

# %%
# speration in independant and dependant features

X = df2.drop("Birth_Weight",axis=1) 
y = df2["Birth_Weight"]

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((132, 5), (57, 5))

# %%
# correlation of traning data 

import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
df2.head()
# Out:
#    Mom_weight  Mom_height  Mom_Age  Religion  Gender  Birth_Weight
# 0          41         152       25         1       1          2.06
# 1          42         157       25         3       1          1.70
# 2          44         153       23         2       1          1.59
# 3          45         177       19         2       1          2.73
# 4          46         160       19         2       1          2.08

# %%
# pipeline for scaling and also null values imputation , there is no any missing data in this dataset but still i have implement
# this for future data

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    #     ..... add as many as you want in your pipeline
    ('std_scaler', StandardScaler()),
])

# %%
X= my_pipeline.fit_transform(X)

# %%
print(X.shape)
X = pd.DataFrame(X)
X.head()
# Out:
# (189, 5)
#           0         1         2         3         4
# 0 -2.423433 -2.236449  0.333401 -0.983993 -0.550861
# 1 -2.322833 -1.678075  0.333401  1.495669 -0.550861
# 2 -2.121635 -2.124774 -0.045054  0.255838 -0.550861
# 3 -2.021035  0.555419 -0.801965  0.255838 -0.550861
# 4 -1.920436 -1.343051 -0.801965  0.255838 -0.550861

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ## Implementation of KNN algorithm

# %%
# function for finding best neighbor value / hyperparameter tunning
error_rate = []
for i in range(1,40):
    
    knn = KNeighborsRegressor(n_neighbors=i)
    knn.fit(X_train,y_train)
    predctions_i = knn.predict(X_test)
    error_rate.append(np.mean(predctions_i != y_test))

# %%
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn_Regressor=KNeighborsRegressor(n_neighbors=1)
knn_Regressor.fit(X_train,y_train)
knn_predictions=knn_Regressor.predict(X_test)
knn_mean_squared_error=mean_squared_error(y_test,knn_predictions)
print('mse : ',knn_mean_squared_error)
rmse = math.sqrt(knn_mean_squared_error)
print('rmse: ', rmse)
print('R2 score: ',r2_score(y_test, knn_predictions))
# Out:
# mse :  0.23030701754385968
# rmse:  0.4799031335007719
# R2 score:  0.45279267027713876

# %% [markdown]
# ## Implementation of random Forest using GridSearchCV algorithm

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [10,15],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5,6],
    'min_samples_split': [3,4,5,6],
    'n_estimators': [100, 200, 250, 300, 350, 400]
}
# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 0)

# Fit the grid search to the data
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [10, 15],
#                          'max_features': [2, 3],
#                          'min_samples_leaf': [3, 4, 5, 6],
#                          'min_samples_split': [3, 4, 5, 6],
#                          'n_estimators': [100, 200, 250, 300, 350, 400]})

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 15,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# RandomForestRegressor(max_depth=15, max_features=3, min_samples_leaf=3,
#                       min_samples_split=5)

# %%
rf_predict = grid_search.predict(X_test)

# %%
rf_mean_squared_error=mean_squared_error(y_test,rf_predict)
print('mse : ',rf_mean_squared_error)
rmse = math.sqrt(rf_mean_squared_error)
print('rmse: ', rmse)
print('R2 score: ',r2_score(y_test, rf_predict))
# Out:
# mse :  0.09881270689605434
# rmse:  0.3143448852710258
# R2 score:  0.7652219282767606

# %% [markdown]
# ## i have implemented the model with two algorithm
# ## Random forest using GridSearchCV gaves me more good accuracy then KNN if we check the MSE, RME and R2 score then will get the accuracy
